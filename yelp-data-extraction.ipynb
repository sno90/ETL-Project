# %% [markdown]
# ## Get DC Museums from Yelp

# %%
# Imports dependencies
import requests
import json
import pandas as pd

# %%
# Set up the API call web location
url = 'https://api.yelp.com/v3/businesses/search'

# %%
# Register to use the Yelp API and get an API Key AND
#Import API key using config
# from config import api_key

# %%
# Search parameters 
params = {
    'term': 'museum',
    'location': 'DC',
    'limit': 20
}

# Authorization headers
# repalce yelp api key 
headers = {
    'Authorization': 'Bearer TyIifSoCRspOE-BB1t6Dk4APQ6m4MKKjJEnMz5tW45SKwO2GFmlVJKmOVfq6MrMvjasC8VLLLfJiCJbE11AF87JZXtdAFh3TKbr0lrSxuuS7H9YvXV75E88v0zdoXXYx'
}

# %%
# Perform API request
data = requests.get(url, params=params, headers=headers)

# %%
# Grab data from the response
parsed = json.loads(data.text)

# %%
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "businesses": [
#         {
#             "id": "4yHn40qEBW3frxTZfDyH3Q",
#             "alias": "smithsonian-national-museum-of-natural-history-washington",
#             "name": "Smithsonian National Museum of Natural History",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/HVuCM8QXW-ivokNufjIYfg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/smithsonian-national-museum-of-natural-history-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 1002,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.891608,
#                 "longitude": -77.026136
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "1000 Constitution Ave NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20004",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "1000 Constitution Ave NW",
#                     "Washington, DC 20004"
#                 ]
#             },
#             "phone": "+12026331000",
#             "display_phone": "(202) 633-1000",
#             "distance": 2223.35628229635
#         },
#         {
#             "id": "vtjhJ6PdIuF5XPDOmFiLEg",
#             "alias": "newseum-washington",
#             "name": "Newseum",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Xw3d73QcfRE03R4fqQaQaw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/newseum-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 920,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8932753657687,
#                 "longitude": -77.0193302238685
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "555 Pennsylvania Ave NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20001",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "555 Pennsylvania Ave NW",
#                     "Washington, DC 20001"
#                 ]
#             },
#             "phone": "+18886397386",
#             "display_phone": "(888) 639-7386",
#             "distance": 2229.7730075781283
#         },
#         {
#             "id": "Yu8__wnueveRyFTDY3cSog",
#             "alias": "smithsonian-national-air-and-space-museum-washington-2",
#             "name": "Smithsonian National Air and Space Museum",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/U1TUoltrX2HbtMOaqaVfXg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/smithsonian-national-air-and-space-museum-washington-2?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 1066,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 38.888165,
#                 "longitude": -77.01987
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "Independence Ave And 6th St SW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20560",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "Independence Ave And 6th St SW",
#                     "Washington, DC 20560"
#                 ]
#             },
#             "phone": "+12026331000",
#             "display_phone": "(202) 633-1000",
#             "distance": 2735.435963265533
#         },
#         {
#             "id": "Vy5uhUmLrLpg5lgN4-b_IA",
#             "alias": "national-gallery-of-art-washington",
#             "name": "National Gallery of Art",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/SZIJ4smM2MYaoAf_J3SLIg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/national-gallery-of-art-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 653,
#             "categories": [
#                 {
#                     "alias": "artmuseums",
#                     "title": "Art Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8913416579172,
#                 "longitude": -77.0198351875512
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "6th St & Constitution Ave NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20001",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "6th St & Constitution Ave NW",
#                     "Washington, DC 20001"
#                 ]
#             },
#             "phone": "+12027374215",
#             "display_phone": "(202) 737-4215",
#             "distance": 2407.5129105888936
#         },
#         {
#             "id": "EnvFlAlIKMMwSxVWCyIsng",
#             "alias": "national-museum-of-american-history-washington",
#             "name": "National Museum of American History",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Tyb1Z1q2W3k1JDRt-pHYmA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/national-museum-of-american-history-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 629,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 38.892109,
#                 "longitude": -77.031948
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "14TH St And Constitution Ave NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20002",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "14TH St And Constitution Ave NW",
#                     "Washington, DC 20002"
#                 ]
#             },
#             "phone": "+12026331000",
#             "display_phone": "(202) 633-1000",
#             "distance": 2136.227149816889
#         },
#         {
#             "id": "iD7F-j5XvDB7a1eDuwPGQw",
#             "alias": "united-states-holocaust-memorial-museum-washington",
#             "name": "United States Holocaust Memorial Museum",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/QNDf29bwp6SvWkPafPhoIw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/united-states-holocaust-memorial-museum-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 753,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.886664736668,
#                 "longitude": -77.032680915553
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "100 Raoul Wallenberg Pl SW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20024",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "100 Raoul Wallenberg Pl SW",
#                     "Washington, DC 20024"
#                 ]
#             },
#             "phone": "+12024880400",
#             "display_phone": "(202) 488-0400",
#             "distance": 2744.2898102167237
#         },
#         {
#             "id": "RStKH-TH6_e_A1f-K_zZNA",
#             "alias": "national-museum-of-african-american-history-and-culture-washington",
#             "name": "National Museum of African American History and Culture",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/C76rPXereap9SeQh9cGnyw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/national-museum-of-african-american-history-and-culture-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 763,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8910644,
#                 "longitude": -77.032617
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "1400 Constitution Ave NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20560",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "1400 Constitution Ave NW",
#                     "Washington, DC 20560"
#                 ]
#             },
#             "phone": "+18447503012",
#             "display_phone": "(844) 750-3012",
#             "distance": 2255.8777347015266
#         },
#         {
#             "id": "CuQx3ueZjpIppxmUE_2wbg",
#             "alias": "united-states-botanic-garden-washington",
#             "name": "United States Botanic Garden",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/CqrVkAwaHrbYqVsbeTVrug/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/united-states-botanic-garden-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 456,
#             "categories": [
#                 {
#                     "alias": "gardens",
#                     "title": "Botanical Gardens"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8880082580276,
#                 "longitude": -77.0127871429638
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "100 Maryland Ave SW",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20001",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "100 Maryland Ave SW",
#                     "Washington, DC 20001"
#                 ]
#             },
#             "phone": "+12022258333",
#             "display_phone": "(202) 225-8333",
#             "distance": 3015.080740329075
#         },
#         {
#             "id": "KVcGvgj_p4rQmmAYOV14jA",
#             "alias": "national-portrait-gallery-washington-3",
#             "name": "National Portrait Gallery",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/w8va5RmRk9xgHshZdOelZw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/national-portrait-gallery-washington-3?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 554,
#             "categories": [
#                 {
#                     "alias": "artmuseums",
#                     "title": "Art Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8978591623305,
#                 "longitude": -77.02331371296
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "8TH St And F St NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20001",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "8TH St And F St NW",
#                     "Washington, DC 20001"
#                 ]
#             },
#             "phone": "+12026338300",
#             "display_phone": "(202) 633-8300",
#             "distance": 1622.7764396172004
#         },
#         {
#             "id": "Vm2aFvM1UCFe6gNE_xaFSA",
#             "alias": "smithsonian-american-art-museum-renwick-gallery-washington",
#             "name": "Smithsonian American Art Museum Renwick Gallery",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/QYd6zIoItrXiSdGv_gUlOA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/smithsonian-american-art-museum-renwick-gallery-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 409,
#             "categories": [
#                 {
#                     "alias": "artmuseums",
#                     "title": "Art Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8990663354408,
#                 "longitude": -77.0390694999682
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "800 G St NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20006",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "800 G St NW",
#                     "Washington, DC 20006"
#                 ]
#             },
#             "phone": "+12023571300",
#             "display_phone": "(202) 357-1300",
#             "distance": 1542.9210921920237
#         },
#         {
#             "id": "YqvnRwMPIsfDraHup-94PA",
#             "alias": "international-spy-museum-washington-2",
#             "name": "International Spy Museum",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Qr1WqngmvdIQuK0LNzPCYA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/international-spy-museum-washington-2?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 923,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 38.8836949,
#                 "longitude": -77.0254819
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "700 L'Enfant Plz",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20024",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "700 L'Enfant Plz",
#                     "Washington, DC 20024"
#                 ]
#             },
#             "phone": "+12023937798",
#             "display_phone": "(202) 393-7798",
#             "distance": 3081.8569521619697
#         },
#         {
#             "id": "mUyVr1BJKhLdjrxzoVtq2A",
#             "alias": "hirshhorn-museum-and-sculpture-garden-washington-2",
#             "name": "Hirshhorn Museum & Sculpture Garden",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/nXzo8RueEm4nZpo3qBLsxA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/hirshhorn-museum-and-sculpture-garden-washington-2?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 410,
#             "categories": [
#                 {
#                     "alias": "galleries",
#                     "title": "Art Galleries"
#                 },
#                 {
#                     "alias": "artmuseums",
#                     "title": "Art Museums"
#                 },
#                 {
#                     "alias": "arttours",
#                     "title": "Art Tours"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 38.8881190707804,
#                 "longitude": -77.022978883606
#             },
#             "transactions": [],
#             "price": "$",
#             "location": {
#                 "address1": "7th St & Independence Ave Sw",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20560",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "7th St & Independence Ave Sw",
#                     "Washington, DC 20560"
#                 ]
#             },
#             "phone": "+12026331000",
#             "display_phone": "(202) 633-1000",
#             "distance": 2660.793259808245
#         },
#         {
#             "id": "YRH5SVwGe6GxQ2YYSSitTA",
#             "alias": "museum-of-the-bible-washington-2",
#             "name": "Museum of the Bible",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/wfSArrnsbjdZ_EW0QeUPUg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/museum-of-the-bible-washington-2?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 219,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8848399,
#                 "longitude": -77.01714
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "400 4th St SW",
#                 "address2": "",
#                 "address3": null,
#                 "city": "Washington, DC",
#                 "zip_code": "20024",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "400 4th St SW",
#                     "Washington, DC 20024"
#                 ]
#             },
#             "phone": "+18664306682",
#             "display_phone": "(866) 430-6682",
#             "distance": 3199.839461777409
#         },
#         {
#             "id": "HI35IBk0HRV28TQbIXaFyg",
#             "alias": "national-geographic-museum-washington-2",
#             "name": "National Geographic Museum",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/NkeTSPm9JRWJTGpMJst7kw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/national-geographic-museum-washington-2?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 240,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 },
#                 {
#                     "alias": "kids_activities",
#                     "title": "Kids Activities"
#                 }
#             ],
#             "rating": 3.5,
#             "coordinates": {
#                 "latitude": 38.9051403613161,
#                 "longitude": -77.03810995
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "1145 17th St NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20036",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "1145 17th St NW",
#                     "Washington, DC 20036"
#                 ]
#             },
#             "phone": "+12028577700",
#             "display_phone": "(202) 857-7700",
#             "distance": 941.2456453133299
#         },
#         {
#             "id": "MHxs5rJrPFgJtMtZxZg-9A",
#             "alias": "fords-theatre-washington",
#             "name": "Ford's Theatre",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/TMxzyiWcJcjDP1X0-9f3pQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/fords-theatre-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 426,
#             "categories": [
#                 {
#                     "alias": "theater",
#                     "title": "Performing Arts"
#                 },
#                 {
#                     "alias": "landmarks",
#                     "title": "Landmarks & Historical Buildings"
#                 },
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.89664,
#                 "longitude": -77.02565
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "511 10th St NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20004",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "511 10th St NW",
#                     "Washington, DC 20004"
#                 ]
#             },
#             "phone": "+12023474833",
#             "display_phone": "(202) 347-4833",
#             "distance": 1683.0459532734205
#         },
#         {
#             "id": "6ZuKGMXVj-t0uoXdJaYE3Q",
#             "alias": "national-archives-and-records-administration-washington",
#             "name": "National Archives and Records Administration",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/3VDtFAmlDs3BmCwT-O2DSg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/national-archives-and-records-administration-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 360,
#             "categories": [
#                 {
#                     "alias": "landmarks",
#                     "title": "Landmarks & Historical Buildings"
#                 },
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8928468314868,
#                 "longitude": -77.0227244493904
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "700 Pennsylvania Ave NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20408",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "700 Pennsylvania Ave NW",
#                     "Washington, DC 20408"
#                 ]
#             },
#             "phone": "+18662726272",
#             "display_phone": "(866) 272-6272",
#             "distance": 2162.5175008785955
#         },
#         {
#             "id": "NPkJ2f8b3dX7PB5O-BnubA",
#             "alias": "the-kreeger-museum-washington",
#             "name": "The Kreeger Museum",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/0cA2tGOP6U1TXHW7sBSTzA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-kreeger-museum-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 48,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.92211,
#                 "longitude": -77.08843
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "2401 Foxhall Rd NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20007",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "2401 Foxhall Rd NW",
#                     "Washington, DC 20007"
#                 ]
#             },
#             "phone": "+12023373050",
#             "display_phone": "(202) 337-3050",
#             "distance": 5165.8521216722975
#         },
#         {
#             "id": "1KBpIjO1qI7jekORNuCEiQ",
#             "alias": "national-postal-museum-washington",
#             "name": "National Postal Museum",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/i3OnaWmEXEfxH0LbVff39Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/national-postal-museum-washington?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 160,
#             "categories": [
#                 {
#                     "alias": "museums",
#                     "title": "Museums"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.898101,
#                 "longitude": -77.008239
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "2 Massachusetts Ave NE",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20002",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "2 Massachusetts Ave NE",
#                     "Washington, DC 20002"
#                 ]
#             },
#             "phone": "+12026335555",
#             "display_phone": "(202) 633-5555",
#             "distance": 2430.868277453264
#         },
#         {
#             "id": "4G3-8BgcUR137kRduRY_RA",
#             "alias": "library-of-congress-washington-3",
#             "name": "Library of Congress",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/QvQkS3eTmD-DH5PIDMnOFw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/library-of-congress-washington-3?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 450,
#             "categories": [
#                 {
#                     "alias": "libraries",
#                     "title": "Libraries"
#                 },
#                 {
#                     "alias": "landmarks",
#                     "title": "Landmarks & Historical Buildings"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 38.8887325486836,
#                 "longitude": -77.0045020200387
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "101 Independence Ave SE",
#                 "address2": null,
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20540",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "101 Independence Ave SE",
#                     "Washington, DC 20540"
#                 ]
#             },
#             "phone": "+12027075000",
#             "display_phone": "(202) 707-5000",
#             "distance": 3377.785238883248
#         },
#         {
#             "id": "uU2_INTiYRGSkSwdb49eWQ",
#             "alias": "the-phillips-collection-washington-3",
#             "name": "The Phillips Collection",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/nt4e8slfaIhGWrW7ladkVQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/the-phillips-collection-washington-3?adjust_creative=6HZ6vKVqDOdS7DxxBBwKhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=6HZ6vKVqDOdS7DxxBBwKhw",
#             "review_count": 211,
#             "categories": [
#                 {
#                     "alias": "artmuseums",
#                     "title": "Art Museums"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 38.911477119043,
#                 "longitude": -77.0468060633715
#             },
#             "transactions": [],
#             "location": {
#                 "address1": "1600 21st St NW",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Washington, DC",
#                 "zip_code": "20009",
#                 "country": "US",
#                 "state": "DC",
#                 "display_address": [
#                     "1600 21st St NW",
#                     "Washington, DC 20009"
#                 ]
#             },
#             "phone": "+12023872151",
#             "display_phone": "(202) 387-2151",
#             "distance": 1398.9110282303982
#         }
#     ],
#     "total": 351,
#     "region": {
#         "center": {
#             "longitude": -77.0306396484375,
#             "latitude": 38.911293573163775
#         }
#     }
# }

# %%
businesses = parsed["businesses"]
 
for business in businesses:
    print("Name:", business["name"])
    print("Rating:", business["rating"])
    print("Address:", " ".join(business["location"]["display_address"]))
    print("Phone:", business["phone"])
    print("\n")
# Out:
# Name: Smithsonian National Museum of Natural History
# Rating: 4.5
# Address: 1000 Constitution Ave NW Washington, DC 20004
# Phone: +12026331000
#
#
# Name: Newseum
# Rating: 4.5
# Address: 555 Pennsylvania Ave NW Washington, DC 20001
# Phone: +18886397386
#
#
# Name: Smithsonian National Air and Space Museum
# Rating: 4.0
# Address: Independence Ave And 6th St SW Washington, DC 20560
# Phone: +12026331000
#
#
# Name: National Gallery of Art
# Rating: 4.5
# Address: 6th St & Constitution Ave NW Washington, DC 20001
# Phone: +12027374215
#
#
# Name: National Museum of American History
# Rating: 4.0
# Address: 14TH St And Constitution Ave NW Washington, DC 20002
# Phone: +12026331000
#
#
# Name: United States Holocaust Memorial Museum
# Rating: 4.5
# Address: 100 Raoul Wallenberg Pl SW Washington, DC 20024
# Phone: +12024880400
#
#
# Name: National Museum of African American History and Culture
# Rating: 4.5
# Address: 1400 Constitution Ave NW Washington, DC 20560
# Phone: +18447503012
#
#
# Name: United States Botanic Garden
# Rating: 4.5
# Address: 100 Maryland Ave SW Washington, DC 20001
# Phone: +12022258333
#
#
# Name: National Portrait Gallery
# Rating: 4.5
# Address: 8TH St And F St NW Washington, DC 20001
# Phone: +12026338300
#
#
# Name: Smithsonian American Art Museum Renwick Gallery
# Rating: 4.5
# Address: 800 G St NW Washington, DC 20006
# Phone: +12023571300
#
#
# Name: International Spy Museum
# Rating: 3.5
# Address: 700 L'Enfant Plz Washington, DC 20024
# Phone: +12023937798
#
#
# Name: Hirshhorn Museum & Sculpture Garden
# Rating: 4.0
# Address: 7th St & Independence Ave Sw Washington, DC 20560
# Phone: +12026331000
#
#
# Name: Museum of the Bible
# Rating: 4.5
# Address: 400 4th St SW Washington, DC 20024
# Phone: +18664306682
#
#
# Name: National Geographic Museum
# Rating: 3.5
# Address: 1145 17th St NW Washington, DC 20036
# Phone: +12028577700
#
#
# Name: Ford's Theatre
# Rating: 4.5
# Address: 511 10th St NW Washington, DC 20004
# Phone: +12023474833
#
#
# Name: National Archives and Records Administration
# Rating: 4.5
# Address: 700 Pennsylvania Ave NW Washington, DC 20408
# Phone: +18662726272
#
#
# Name: The Kreeger Museum
# Rating: 4.5
# Address: 2401 Foxhall Rd NW Washington, DC 20007
# Phone: +12023373050
#
#
# Name: National Postal Museum
# Rating: 4.5
# Address: 2 Massachusetts Ave NE Washington, DC 20002
# Phone: +12026335555
#
#
# Name: Library of Congress
# Rating: 4.5
# Address: 101 Independence Ave SE Washington, DC 20540
# Phone: +12027075000
#
#
# Name: The Phillips Collection
# Rating: 4.0
# Address: 1600 21st St NW Washington, DC 20009
# Phone: +12023872151

# %%
# create empty lists for museum data
museum_names = []
museum_ratings = []
museum_review_counts = []

# loop through each museum data, grab relevent info, and append it to empty lists 
for business in businesses:
    names = business['name']
    museum_names.append(names)
    ratings = business['rating']
    museum_ratings.append(ratings)
    counts = business['review_count']
    museum_review_counts.append(counts)

# %%
# create museum df
museum_df = pd.DataFrame(
    {'museum names': museum_names,
     'museum ratings': museum_ratings, 
     'number of museum reviews': museum_review_counts
    })

# %%
#Set index to count museums and add identifier
museum_df = museum_df.reset_index(drop=True)
museum_df
# Out:
#                                          museum names  museum ratings  \
# 0      Smithsonian National Museum of Natural History             4.5
# 1                                             Newseum             4.5
# 2           Smithsonian National Air and Space Museum             4.0
# 3                             National Gallery of Art             4.5
# 4                 National Museum of American History             4.0
# 5             United States Holocaust Memorial Museum             4.5
# 6   National Museum of African American History an...             4.5
# 7                        United States Botanic Garden             4.5
# 8                           National Portrait Gallery             4.5
# 9     Smithsonian American Art Museum Renwick Gallery             4.5
# 10                           International Spy Museum             3.5
# 11                Hirshhorn Museum & Sculpture Garden             4.0
# 12                                Museum of the Bible             4.5
# 13                         National Geographic Museum             3.5
# 14                                     Ford's Theatre             4.5
# 15       National Archives and Records Administration             4.5
# 16                                 The Kreeger Museum             4.5
# 17                             National Postal Museum             4.5
# 18                                Library of Congress             4.5
# 19                            The Phillips Collection             4.0
#
#     number of museum reviews
# 0                       1002
# 1                        920
# 2                       1066
# 3                        653
# 4                        629
# 5                        753
# 6                        763
# 7                        456
# 8                        554
# 9                        409
# 10                       923
# 11                       410
# 12                       219
# 13                       240
# 14                       426
# 15                       360
# 16                        48
# 17                       160
# 18                       450
# 19                       211

# %%
#Add column of museums names without spaces, for instagram hashtag
#Reset index to keep original index
museum_df['museum names no space'] = museum_df['museum names'].str.replace(" ","").str.replace("&","").str.replace("'","")
museum_df.reset_index(inplace=True, drop=True)

# %%
#Rearrange columns 
yelp_museum_df = museum_df[['museum names', 'museum names no space', 'museum ratings', 'number of museum reviews']]
yelp_museum_df
# Out:
#                                          museum names  \
# 0      Smithsonian National Museum of Natural History
# 1                                             Newseum
# 2           Smithsonian National Air and Space Museum
# 3                             National Gallery of Art
# 4                 National Museum of American History
# 5             United States Holocaust Memorial Museum
# 6   National Museum of African American History an...
# 7                        United States Botanic Garden
# 8                           National Portrait Gallery
# 9     Smithsonian American Art Museum Renwick Gallery
# 10                           International Spy Museum
# 11                Hirshhorn Museum & Sculpture Garden
# 12                                Museum of the Bible
# 13                         National Geographic Museum
# 14                                     Ford's Theatre
# 15       National Archives and Records Administration
# 16                                 The Kreeger Museum
# 17                             National Postal Museum
# 18                                Library of Congress
# 19                            The Phillips Collection
#
#                                museum names no space  museum ratings  \
# 0          SmithsonianNationalMuseumofNaturalHistory             4.5
# 1                                            Newseum             4.5
# 2               SmithsonianNationalAirandSpaceMuseum             4.0
# 3                               NationalGalleryofArt             4.5
# 4                    NationalMuseumofAmericanHistory             4.0
# 5                UnitedStatesHolocaustMemorialMuseum             4.5
# 6   NationalMuseumofAfricanAmericanHistoryandCulture             4.5
# 7                          UnitedStatesBotanicGarden             4.5
# 8                            NationalPortraitGallery             4.5
# 9         SmithsonianAmericanArtMuseumRenwickGallery             4.5
# 10                            InternationalSpyMuseum             3.5
# 11                    HirshhornMuseumSculptureGarden             4.0
# 12                                  MuseumoftheBible             4.5
# 13                          NationalGeographicMuseum             3.5
# 14                                      FordsTheatre             4.5
# 15          NationalArchivesandRecordsAdministration             4.5
# 16                                  TheKreegerMuseum             4.5
# 17                              NationalPostalMuseum             4.5
# 18                                 LibraryofCongress             4.5
# 19                             ThePhillipsCollection             4.0
#
#     number of museum reviews
# 0                       1002
# 1                        920
# 2                       1066
# 3                        653
# 4                        629
# 5                        753
# 6                        763
# 7                        456
# 8                        554
# 9                        409
# 10                       923
# 11                       410
# 12                       219
# 13                       240
# 14                       426
# 15                       360
# 16                        48
# 17                       160
# 18                       450
# 19                       211

# %%
yelp_museum_df.to_csv(r'yelp_museums.csv')

# %%
museum_df =
